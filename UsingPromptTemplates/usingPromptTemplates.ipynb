# %%
! pip install semantic-kernel
# Out:
# Requirement already satisfied: semantic-kernel in c:\users\rithv\anaconda3\lib\site-packages (0.9.0b1)
# Requirement already satisfied: aiofiles<24.0.0,>=23.1.0 in c:\users\rithv\anaconda3\lib\site-packages (from semantic-kernel) (23.2.1)
# Requirement already satisfied: aiohttp<4.0,>=3.8 in c:\users\rithv\anaconda3\lib\site-packages (from semantic-kernel) (3.10.5)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\rithv\anaconda3\lib\site-packages (from semantic-kernel) (0.7.1)
# Requirement already satisfied: motor<4.0.0,>=3.3.2 in c:\users\rithv\anaconda3\lib\site-packages (from semantic-kernel) (3.7.1)
# Requirement already satisfied: numpy<2.0.0,>=1.24.2 in c:\users\rithv\anaconda3\lib\site-packages (from semantic-kernel) (1.26.4)
# Requirement already satisfied: openai>=1.0 in c:\users\rithv\anaconda3\lib\site-packages (from semantic-kernel) (2.15.0)
# Requirement already satisfied: openapi_core<0.19.0,>=0.18.0 in c:\users\rithv\anaconda3\lib\site-packages (from semantic-kernel) (0.18.2)
# Requirement already satisfied: prance<24.0.0.0,>=23.6.21.0 in c:\users\rithv\anaconda3\lib\site-packages (from semantic-kernel) (23.6.21.0)
# Requirement already satisfied: pydantic>2 in c:\users\rithv\anaconda3\lib\site-packages (from semantic-kernel) (2.8.2)
# Requirement already satisfied: python-dotenv==1.0.1 in c:\users\rithv\anaconda3\lib\site-packages (from semantic-kernel) (1.0.1)
# Requirement already satisfied: regex<2024.0.0,>=2023.6.3 in c:\users\rithv\anaconda3\lib\site-packages (from semantic-kernel) (2023.12.25)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\rithv\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\rithv\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rithv\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rithv\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rithv\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\rithv\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel) (1.11.0)
# Requirement already satisfied: pymongo<5.0,>=4.9 in c:\users\rithv\anaconda3\lib\site-packages (from motor<4.0.0,>=3.3.2->semantic-kernel) (4.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\rithv\anaconda3\lib\site-packages (from openai>=1.0->semantic-kernel) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\rithv\anaconda3\lib\site-packages (from openai>=1.0->semantic-kernel) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\rithv\anaconda3\lib\site-packages (from openai>=1.0->semantic-kernel) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\rithv\anaconda3\lib\site-packages (from openai>=1.0->semantic-kernel) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\rithv\anaconda3\lib\site-packages (from openai>=1.0->semantic-kernel) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\rithv\anaconda3\lib\site-packages (from openai>=1.0->semantic-kernel) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\rithv\anaconda3\lib\site-packages (from openai>=1.0->semantic-kernel) (4.11.0)
# Requirement already satisfied: asgiref<4.0.0,>=3.6.0 in c:\users\rithv\anaconda3\lib\site-packages (from openapi_core<0.19.0,>=0.18.0->semantic-kernel) (3.11.0)
# Requirement already satisfied: isodate in c:\users\rithv\anaconda3\lib\site-packages (from openapi_core<0.19.0,>=0.18.0->semantic-kernel) (0.7.2)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in c:\users\rithv\anaconda3\lib\site-packages (from openapi_core<0.19.0,>=0.18.0->semantic-kernel) (4.23.0)
# Requirement already satisfied: jsonschema-spec<0.3.0,>=0.2.3 in c:\users\rithv\anaconda3\lib\site-packages (from openapi_core<0.19.0,>=0.18.0->semantic-kernel) (0.2.4)
# Requirement already satisfied: more-itertools in c:\users\rithv\anaconda3\lib\site-packages (from openapi_core<0.19.0,>=0.18.0->semantic-kernel) (10.3.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in c:\users\rithv\anaconda3\lib\site-packages (from openapi_core<0.19.0,>=0.18.0->semantic-kernel) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in c:\users\rithv\anaconda3\lib\site-packages (from openapi_core<0.19.0,>=0.18.0->semantic-kernel) (0.7.2)
# Requirement already satisfied: parse in c:\users\rithv\anaconda3\lib\site-packages (from openapi_core<0.19.0,>=0.18.0->semantic-kernel) (1.20.2)
# Requirement already satisfied: werkzeug in c:\users\rithv\anaconda3\lib\site-packages (from openapi_core<0.19.0,>=0.18.0->semantic-kernel) (3.0.3)
# Requirement already satisfied: chardet>=3.0 in c:\users\rithv\anaconda3\lib\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel) (4.0.0)
# Requirement already satisfied: ruamel.yaml>=0.17.10 in c:\users\rithv\anaconda3\lib\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel) (0.18.6)
# Requirement already satisfied: requests>=2.25 in c:\users\rithv\anaconda3\lib\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel) (2.32.3)
# Requirement already satisfied: six~=1.15 in c:\users\rithv\appdata\roaming\python\python312\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\rithv\appdata\roaming\python\python312\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel) (24.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\rithv\anaconda3\lib\site-packages (from pydantic>2->semantic-kernel) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\rithv\anaconda3\lib\site-packages (from pydantic>2->semantic-kernel) (2.20.1)
# Requirement already satisfied: idna>=2.8 in c:\users\rithv\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.0->semantic-kernel) (3.7)
# Requirement already satisfied: certifi in c:\users\rithv\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\rithv\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rithv\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.0->semantic-kernel) (0.14.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\rithv\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.19.0,>=0.18.0->semantic-kernel) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\rithv\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.19.0,>=0.18.0->semantic-kernel) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\rithv\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.19.0,>=0.18.0->semantic-kernel) (0.10.6)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\rithv\anaconda3\lib\site-packages (from jsonschema-spec<0.3.0,>=0.2.3->openapi_core<0.19.0,>=0.18.0->semantic-kernel) (6.0.1)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in c:\users\rithv\anaconda3\lib\site-packages (from jsonschema-spec<0.3.0,>=0.2.3->openapi_core<0.19.0,>=0.18.0->semantic-kernel) (0.4.4)
# Requirement already satisfied: rfc3339-validator in c:\users\rithv\anaconda3\lib\site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.19.0,>=0.18.0->semantic-kernel) (0.1.4)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in c:\users\rithv\anaconda3\lib\site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.19.0,>=0.18.0->semantic-kernel) (0.3.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in c:\users\rithv\anaconda3\lib\site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.19.0,>=0.18.0->semantic-kernel) (1.10.0)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in c:\users\rithv\anaconda3\lib\site-packages (from pymongo<5.0,>=4.9->motor<4.0.0,>=3.3.2->semantic-kernel) (2.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rithv\anaconda3\lib\site-packages (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic-kernel) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rithv\anaconda3\lib\site-packages (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic-kernel) (2.2.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\rithv\anaconda3\lib\site-packages (from ruamel.yaml>=0.17.10->prance<24.0.0.0,>=23.6.21.0->semantic-kernel) (0.2.8)
# Requirement already satisfied: colorama in c:\users\rithv\appdata\roaming\python\python312\site-packages (from tqdm>4->openai>=1.0->semantic-kernel) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\rithv\anaconda3\lib\site-packages (from werkzeug->openapi_core<0.19.0,>=0.18.0->semantic-kernel) (2.1.3)

# %%
import semantic_kernel as sk
import semantic_kernel.connectors.ai.open_ai as sk_oai
from semantic_kernel.prompt_template.input_variable import InputVariable
from dotenv import dotenv_values

config = dotenv_values()
kernel = sk.Kernel()

# %%
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion
kernel.add_service(
    AzureChatCompletion(
        service_id="az-chat-completion",
        deployment_name=config["AZURE_OPENAI_DEPLOYMENT"],
        endpoint=config["AZURE_OPENAI_ENDPOINT"],
        api_version=config["AZURE_API_VERSION"],
        api_key=config["AZURE_OPENAI_API_KEY"]
    )
)

# %%
prompt = "Summarise the given content in 50-70 words - {{$input}}"
execution_settings = sk_oai.OpenAIChatPromptExecutionSettings(
    service_id="az-chat-completion",
    max_tokens=100
)

prompt_template_config = sk.PromptTemplateConfig(
    template= prompt,
    name= "summarise",
    template_format= "semantic-kernel", # theres another format called handlebars - will learn in future videos!
    input_variables= [
        InputVariable(name= "input", description= "The user input", is_required= True)
    ],
    execution_settings= execution_settings
)

summarise = kernel.create_function_from_prompt(
    function_name= "Summariser",
    plugin_name= "SummariserPlugin",
    prompt_template_config= prompt_template_config
)
# Out:
# ---------------------------------------------------------------------------
# FunctionInvalidNameError                  Traceback (most recent call last)
# Cell In[12], line 17
#       2 execution_settings = sk_oai.OpenAIChatPromptExecutionSettings(
#       3     service_id="az-chat-completion",
#       4     max_tokens=100
#       5 )
#       7 prompt_template_config = sk.PromptTemplateConfig(
#       8     template= prompt,
#       9     name= "summarise",
#    (...)
#      14     execution_settings= execution_settings
#      15 )
# ---> 17 summarise = kernel.create_function_from_prompt(
#      18     function_name= "Summariser",
#      19     plugin_name= "SummariserPlugin",
#      20     prompt_template_config= prompt_template_config
#      21 )
#
# File c:\Users\rithv\anaconda3\Lib\site-packages\semantic_kernel\kernel.py:640, in Kernel.create_function_from_prompt(self, function_name, plugin_name, description, prompt, prompt_template_config, prompt_execution_settings, template_format, prompt_template, **kwargs)
#     627     prompt_execution_settings = PromptExecutionSettings(extension_data=kwargs)
#     629 function = KernelFunctionFromPrompt(
#     630     function_name=function_name,
#     631     plugin_name=plugin_name,
#    (...)
#     637     prompt_execution_settings=prompt_execution_settings,
#     638 )
# --> 640 self.add_plugin(plugin_name or function.plugin_name, [function])
#     642 return function
#
# File c:\Users\rithv\anaconda3\Lib\site-packages\semantic_kernel\kernel.py:447, in Kernel.add_plugin(self, plugin_name, functions, plugin)
#     444     plugin = KernelPlugin(name=plugin_name, functions=functions)
#     446 if plugin_name in self.plugins:
# --> 447     self.plugins.add_functions_to_plugin(functions=functions, plugin_name=plugin_name)
#     448 else:
#     449     self.plugins.add(plugin)
#
# File c:\Users\rithv\anaconda3\Lib\site-packages\semantic_kernel\functions\kernel_plugin_collection.py:123, in KernelPluginCollection.add_functions_to_plugin(self, functions, plugin_name)
#     121 for func in functions:
#     122     if func.name in self.plugins[plugin_name].functions:
# --> 123         raise FunctionInvalidNameError(
#     124             f"Function with name '{func.name}' already exists in plugin '{plugin_name}'"
#     125         )
#     126     self.plugins[plugin_name].functions[func.name] = func
#
# FunctionInvalidNameError: Function with name 'Summariser' already exists in plugin 'SummariserPlugin'

# %%
input_text = """Apricots are small, golden-orange fruits that belong to the stone fruit family, which also includes peaches, plums, and cherries. They are believed to have originated in Central Asia and have been cultivated for thousands of years. Today, apricots are grown in many parts of the world, including Turkey, Iran, Italy, and the United States.

Apricots are well known for their sweet, slightly tangy flavour and soft texture. They can be eaten fresh or dried, and are commonly used in jams, desserts, juices, and savoury dishes. Dried apricots are especially popular because they last longer and contain concentrated nutrients.

Nutritionally, apricots are a healthy food choice. They are rich in vitamins A and C, which help support eye health and the immune system. Apricots also contain fibre, which aids digestion, and antioxidants that help protect the body from damage caused by harmful molecules called free radicals.

Because of their taste, versatility, and health benefits, apricots remain a popular fruit enjoyed by people all around the world."""

summary = await kernel.invoke(summarise, sk.KernelArguments(input=input_text))
print(summary)
# Out:
# Apricots are small, golden-orange stone fruits related to peaches, plums, and cherries, believed to have originated in Central Asia. Grown globally, they are known for their sweet, tangy flavor and soft texture, enjoyed fresh or dried in various dishes. Nutritionally, apricots are rich in vitamins A and C, fiber, and antioxidants, making them a healthy choice. Their taste and versatility contribute to their popularity worldwide.
